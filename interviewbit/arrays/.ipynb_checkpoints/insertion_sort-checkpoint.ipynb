# %%
array_1 = [31,29,27,28,19,17,15]

# %%
def insertion_sort(array_1):
    for i in range(1,len(array_1)):
        current_number = array_1[i]
        j = i-1
        while j>=0 and current_number < array_1[j]:
            print("origin array",array_1)
            print("i: {} & j: {}".format(i,j))
            print("current_number: {} & array_1[{}]: {}".format(current_number,j,array_1[j]))
            array_1[j+1]= array_1[j]
            j -=1
            print("Change j: ",j)
            print("array: ",array_1)
            print("-"*30)
        print("array_1[{}] = {}".format(j+1,array_1[j+1]))
        array_1[j+1] = current_number
    print("Finish array_1:",array_1)
    return array_1

array_new = insertion_sort(array_1)
# Out:
# origin array [31, 29, 27, 28, 19, 17, 15]
# i: 1 & j: 0
# current_number: 29 & array_1[0]: 31
# Change j:  -1
# array:  [31, 31, 27, 28, 19, 17, 15]
# ------------------------------
# array_1[0] = 31
# origin array [29, 31, 27, 28, 19, 17, 15]
# i: 2 & j: 1
# current_number: 27 & array_1[1]: 31
# Change j:  0
# array:  [29, 31, 31, 28, 19, 17, 15]
# ------------------------------
# origin array [29, 31, 31, 28, 19, 17, 15]
# i: 2 & j: 0
# current_number: 27 & array_1[0]: 29
# Change j:  -1
# array:  [29, 29, 31, 28, 19, 17, 15]
# ------------------------------
# array_1[0] = 29
# origin array [27, 29, 31, 28, 19, 17, 15]
# i: 3 & j: 2
# current_number: 28 & array_1[2]: 31
# Change j:  1
# array:  [27, 29, 31, 31, 19, 17, 15]
# ------------------------------
# origin array [27, 29, 31, 31, 19, 17, 15]
# i: 3 & j: 1
# current_number: 28 & array_1[1]: 29
# Change j:  0
# array:  [27, 29, 29, 31, 19, 17, 15]
# ------------------------------
# array_1[1] = 29
# origin array [27, 28, 29, 31, 19, 17, 15]
# i: 4 & j: 3
# current_number: 19 & array_1[3]: 31
# Change j:  2
# array:  [27, 28, 29, 31, 31, 17, 15]
# ------------------------------
# origin array [27, 28, 29, 31, 31, 17, 15]
# i: 4 & j: 2
# current_number: 19 & array_1[2]: 29
# Change j:  1
# array:  [27, 28, 29, 29, 31, 17, 15]
# ------------------------------
# origin array [27, 28, 29, 29, 31, 17, 15]
# i: 4 & j: 1
# current_number: 19 & array_1[1]: 28
# Change j:  0
# array:  [27, 28, 28, 29, 31, 17, 15]
# ------------------------------
# origin array [27, 28, 28, 29, 31, 17, 15]
# i: 4 & j: 0
# current_number: 19 & array_1[0]: 27
# Change j:  -1
# array:  [27, 27, 28, 29, 31, 17, 15]
# ------------------------------
# array_1[0] = 27
# origin array [19, 27, 28, 29, 31, 17, 15]
# i: 5 & j: 4
# current_number: 17 & array_1[4]: 31
# Change j:  3
# array:  [19, 27, 28, 29, 31, 31, 15]
# ------------------------------
# origin array [19, 27, 28, 29, 31, 31, 15]
# i: 5 & j: 3
# current_number: 17 & array_1[3]: 29
# Change j:  2
# array:  [19, 27, 28, 29, 29, 31, 15]
# ------------------------------
# origin array [19, 27, 28, 29, 29, 31, 15]
# i: 5 & j: 2
# current_number: 17 & array_1[2]: 28
# Change j:  1
# array:  [19, 27, 28, 28, 29, 31, 15]
# ------------------------------
# origin array [19, 27, 28, 28, 29, 31, 15]
# i: 5 & j: 1
# current_number: 17 & array_1[1]: 27
# Change j:  0
# array:  [19, 27, 27, 28, 29, 31, 15]
# ------------------------------
# origin array [19, 27, 27, 28, 29, 31, 15]
# i: 5 & j: 0
# current_number: 17 & array_1[0]: 19
# Change j:  -1
# array:  [19, 19, 27, 28, 29, 31, 15]
# ------------------------------
# array_1[0] = 19
# origin array [17, 19, 27, 28, 29, 31, 15]
# i: 6 & j: 5
# current_number: 15 & array_1[5]: 31
# Change j:  4
# array:  [17, 19, 27, 28, 29, 31, 31]
# ------------------------------
# origin array [17, 19, 27, 28, 29, 31, 31]
# i: 6 & j: 4
# current_number: 15 & array_1[4]: 29
# Change j:  3
# array:  [17, 19, 27, 28, 29, 29, 31]
# ------------------------------
# origin array [17, 19, 27, 28, 29, 29, 31]
# i: 6 & j: 3
# current_number: 15 & array_1[3]: 28
# Change j:  2
# array:  [17, 19, 27, 28, 28, 29, 31]
# ------------------------------
# origin array [17, 19, 27, 28, 28, 29, 31]
# i: 6 & j: 2
# current_number: 15 & array_1[2]: 27
# Change j:  1
# array:  [17, 19, 27, 27, 28, 29, 31]
# ------------------------------
# origin array [17, 19, 27, 27, 28, 29, 31]
# i: 6 & j: 1
# current_number: 15 & array_1[1]: 19
# Change j:  0
# array:  [17, 19, 19, 27, 28, 29, 31]
# ------------------------------
# origin array [17, 19, 19, 27, 28, 29, 31]
# i: 6 & j: 0
# current_number: 15 & array_1[0]: 17
# Change j:  -1
# array:  [17, 17, 19, 27, 28, 29, 31]
# ------------------------------
# array_1[0] = 17
# Finish array_1: [15, 17, 19, 27, 28, 29, 31]

# %%
# Worst Case Time Complexity [ Big-O ]: O(n2)
# Best Case Time Complexity [Big-omega]: O(n)
# Average Time Complexity [Big-theta]: O(n2)
# Out:
# [31, 31, 31, 31, 31, 31, 31]
