# %% [markdown]
# ![Screen%20Shot%202021-04-11%20at%2014.48.41.png](attachment:Screen%20Shot%202021-04-11%20at%2014.48.41.png)

# %%
class MovingAverage:

    def __init__(self, size: int):
        """
        Initialize your data structure here.
        """
        self.size = size
        self.queue = []
        

    def next(self, val: int) -> float:
        size = self.size
        queue = self.queue
        queue.append(val)
        sum_window = sum(queue[-size:])
        avg_window = sum_window/min(len(queue),size)
        return avg_window
        


# Your MovingAverage object will be instantiated and called as such:
# obj = MovingAverage(size)
# param_1 = obj.next(val)
